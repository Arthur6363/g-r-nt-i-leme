# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthur6363/goruntu-isleme-ve-nesne-tan-ma/blob/main/Untitled41.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('kişilik.jpeg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1536>

# %%
! sudo apt install tesseract-ocr

# %%
pip install pytesseract

# %%
img = cv2.imread('/content/Ekran görüntüsü 2024-06-10 132858.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=942x162>

# %%
import pytesseract
text=pytesseract.image_to_string(img)
print(text)
# Out:
# — Konvusmanin mihrak noktasi (ehl-i tahkik nezdinde) dért sey
# iizerindedir : 1 — Celil’in (Allahin) sevgisi, 2 — Kalil’in (az’n yani diin-
# yanin) bugzu, 3 — Tenzil’in (Kur’anin) ittibai (yani Kur’ana tabii ol-
# mak) 4 — Tahvilin (Bu halden daha kétii bir hale diigmenin) korkusu-
# dur.

# %%
# !tesseract --list-langs
# Out:
# List of available languages (2):
# eng
# osd

# %%
# !apt-get install tesseract-ocr-lang
# !apt-get install tesseract-ocr-tur

# %%
text=pytesseract.image_to_string(img, lang="tur")
print(text)
# Out:
# — Konuşmanın mihrak noktası (ehl-i tahkik nezdinde) dört şey
# üzerindedir : 1 — Celil'in (Allahın) sevgisi, 2 — Kalil'in (az'ın yani dün-
# yanın) buğzu, 3 — Tenzil'in (Kur'anın) ittiba (yani Kur'ana tabii ol-
# mak) 4 — Tahvilin (Bu halden daha kötü bir hale düşmenin) korkusu-
# dur»
